# %% [markdown]
# <a href="https://colab.research.google.com/github/imfilip/kosaciec/blob/master/matplotlib_styles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1) Import some usefull modules**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **2) Create random data using numpy closure**

# %%
data = np.random.normal(loc=0, scale=1, size=(100,2))
print(f"First 5 rows of data:\n\n {data[:5,:]}")
# Out:
# First 5 rows of data:
#
#  [[ 0.10216833 -1.23166697]
#  [ 1.32834631 -1.3083399 ]
#  [ 0.92425758 -0.01676534]
#  [ 0.37520823  0.52395903]
#  [ 0.79445514 -1.96335247]]

# %% [markdown]
# **3) Basic visualization of data with the use of matplotlib module**
#
# The data are plotted using all available matplotlib styles. It could be usefull to check instantly which one style is appropriate for me.

# %%
style_list = ['default', 'classic'] + sorted(
        style for style in plt.style.available
        if style != 'classic' and not style.startswith('_'))

for st in style_list:
  with plt.rc_context({"figure.max_open_warning": len(style_list)}):
    with plt.style.context(st):
      fig, ax = plt.subplots(figsize=(8,4))
      # fig.tight_layout()
      ax.plot(data[:,0], data[:,1], color='b', linestyle='none', marker='o', markersize=10, alpha=0.3)
      ax.scatter(data[:,0], data[:,1], color='r', alpha=0.3)
      fig.suptitle(st, x=0.01, ha='left', fontsize=14, fontfamily='DejaVu Sans', 
                  fontweight='normal')
